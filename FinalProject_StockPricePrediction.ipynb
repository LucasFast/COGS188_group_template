# %% [markdown]
# # COGS 118B - Final Project

# %% [markdown]
# # ML Stock Price Prediction
#
# ## Group members
#
# - Lucas Fasting
# - Yash Sharma
# - Bryan Nguyen

# %% [markdown]
# # Abstract
# The goal of this project is to predict future stock prices based on historical price data and financial indicators. The dataset we use will consist of more than 10,000 observations and over 10 variables, including stock prices, trading volumes, and technical indicators such as moving averages and Relative Strength Index (RSI). The data we use will be measured, cleaned and formatted in the most efficient way we can. Capturing detailed  trends and market behaviors. Our project will involve feature selection to identify the most relevant predictors, followed by the application of time series forecasting models. We will also use Monte Carlo simulations to model the uncertainty and variability in stock price predictions. This measure of performance of predictive models will be evaluated using Root Mean Squared Error (RMSE) and Mean Absolute Percentage Error (MAPE) to assess their accuracy. Success will be measured by our models' ability to accurately predict stock prices, as it interacts with the stock environment.

# %% [markdown]
# # Background
#
# For years hedge funds have been have been in control of the stock market, dedicating large amounts of capital to spend on due dilligence analysis to find potential investment opportunities. Not only do they have the manpower but they have the mathematical algorithms to automate trades that exectute buy and sell positions with extreme accuracy <a name="fach"></a>[<sup>[1]</sup>](#fachnote). The use of these powerful algorithms is called quant trading. Millions of dollars have been invested in to these algorithms and have given the hedge funds an edge on the market. Often times identifying moves before they happen, capatalizing their percent gain. But as time has gone on, we have gathered historic data on the stock market, providing retail investors with the opportunity to capture, and analyze this data for their own gain. Retail investors will always be delt the losing hand here, but as computing power has become more accessible to the general public; investors at home are exprimenting with their own algorithms using different machine learning techniques.
#
# The application of machine learning to stock market prediction began gaining traction in the late 20th and early 21st centuries. Early models, such as linear regression and decision trees, proved helpful at first initial insights but often struggled with the market's high volitlity and identifying patterns within the market <a name="ballings"></a>[<sup>[2]</sup>](#ballingnote). To address these challenges, researchers began employing more advanced techniques, such as Support Vector Machines (SVM) and ensemble methods like Random Forests and Gradient Boosting Machines (GBM), which could better capture complex relationships between features.
#
# The introduction of time series forecasting models marked a significant advancement in stock market prediction. Models like ARIMA (AutoRegressive Integrated Moving Average) became popular for their ability to model patterns in the data. ARIMA models, however, often required extensive domain knowledge to identify appropriate parameters and could struggle with capturing long-term dependencies<a name="zhang"></a>[<sup>[3]</sup>](#zhangnote). Predicting the stock market has undergone even more change thanks to recent developments in deep learning. Recurrent neural networks (RNNs) of the Long Short-Term Memory (LSTM) kind have shown considerable improvement because of their capacity to recall long-term trends and efficiently handle sequential data.
#
# Predictions about the stock market that are accurate have many uses. They can assist financial institutions and investors in making well-informed decisions, maximizing trading tactics, and most importantly managing risks. Our goal as a group was to not make a program that will trade for you, or take over the due dilligence process. We want to create a tool that we ourselves would use and provide to anyone who would like a useful tool that can help conviction before entering a position in the market utilizing the tools we have learned in this class as well as other machine learning techniques that we could think of.

# %% [markdown]
# # Problem Statement
#
# Clearly describe the problem that you are solving. Avoid ambiguous words. The problem described should be well defined and should have at least one ML-relevant potential solution. Additionally, describe the problem thoroughly such that it is clear that the problem is quantifiable (the problem can be expressed in mathematical or logical terms), measurable (the problem can be measured by some metric and clearly observed), and replicable (the problem can be reproduced and occurs more than once).
#
# The problem we're solving is the inability and lack of tools using AI and ML methods to predict stock prices. Currently it's very difficult to predict future prices. Our problem involves numerical stock data that is quantifiable and able to be analyzed through different machine learning techniques. We have two clear metrics to measure from, with RMSE and MAPE being used. This process can be repeated for different stocks, time periods, and market conditions making it replicable across multiple scenarios. Our objective is to accurately predict prices based on historical data, which can be done by observing and predicting on data from earlier time periods and comparing it to more recent periods.

# %% [markdown]
# # Data
#
# In terms of what our dataset is looking for, we are looking for a dataset that can utilize methods like RMSE (Root Mean Square Error) and MAPE (Mean Absolute Percentage Error) when evaluating the predicted versus actual values of the stock price. Additionally, the dataset should include a diverse range of companies and industries to test the robustness and generalizability of our predictive models. We aim to analyze the temporal patterns in stock prices using advanced machine learning techniques such as LSTM (Long Short-Term Memory) and GRU (Gated Recurrent Unit) to provide accurate stock price predictions.
#
# - **Link/reference to obtain it**:
#   - The dataset can be obtained from [Kaggle: Intro to Recurrent Neural Networks LSTM GRU](https://www.kaggle.com/code/thebrownviking20/intro-to-recurrent-neural-networks-lstm-gru).
#   - The second dataset can be obtained from [$AAPL Option Chains - Q1 2016 to Q1 2023](https://www.kaggle.com/datasets/kylegraupe/aapl-options-data-2016-2020).
#
# - **Description of the size of the dataset (# of variables, # of observations)**:
#   - The dataset includes historical stock prices for multiple companies, with variables such as date, open, high, low, close, volume, and adjusted close. It encompasses thousands of observations over several years.
#
# - **What an observation consists of**:
#   - Each observation represents the stock price data for a single trading day of a specific company.
#
# - **What some critical variables are, how they are represented**:
#   - `Date`: The trading date (e.g., 2021-05-17).
#   - `Open`: The opening price of the stock (e.g., 135.67).
#   - `High`: The highest price of the stock during the trading day (e.g., 137.45).
#   - `Low`: The lowest price of the stock during the trading day (e.g., 133.21).
#   - `Close`: The closing price of the stock (e.g., 136.50).
#   - `Volume`: The number of shares traded (e.g., 1250000).
#   - `Adj Close`: The adjusted closing price accounting for dividends and stock splits (e.g., 136.50).
#
# - **Any special handling, transformations, cleaning, etc. will be needed**:
#   - Data cleaning to handle missing values and outliers.
#   - Normalization or scaling of stock prices to ensure consistent range for model training.
#   - Splitting the dataset into training, validation, and test sets to evaluate model performance.
#   - Feature engineering to create additional variables such as moving averages, technical indicators, and lagged features.

# %% [markdown]
# # Proposed Solution
#
# KNN:
#
# The KNN model will be used on the stock dataset.
#
# Steps to KNN:
# 1. Load data
# 2. Preprocess data
# 3. Split into training/testing
# 4. Model fitting
# 5. Use fitted model to make predictions
# 6. Evaluate performance
#
# DQN:
#
# The DQN model will be used on the stock dataset.
#
# Steps to KNN:
# 1. Load data
# 2. Preprocess data
# 3. Split into training/testing
# 4. Model fitting
# 5. Use fitted model to make predictions
# 6. Evaluate performance
#
# LSTM:
#
# The LSTM model will allow us to see the dependencies within the data. It can be used to learn patterns over long periods of time, which means we can use it for stock prices since there's a lot of stock history.
#
# Steps to LSTM:
# 1. Load data
# 2. Preprocess data
# 3. Split into training/testing
# 4. Create LSTM network
# 5. Train and make predictions
# 6. Evaluate performance

# %% [markdown]
# # Evaluation Metrics
#
# RMSE:
#
# This method will allow us to see the differences between predicted and actual values. It's the square root of the average squared differences between the two values, and the lower it is the better the performance of the model.
#
# $$ \text{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2}$$
#
# MAPE:
#
# This method will allow us to view the accuracy of the predictions as a percentage value. This value is calculated by taking the average absolute percentage difference between the predicted and actual values. The lower the score is, the better the performance of the model.
#
# $$ \text{MAPE} = \frac{100}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|$$
#
# By combining these two models, we will be able to measure our performance accurately. This will be to ensure that our model provides reliable predictions to the best of its ability and prove that it can be used as a financial tool in the market.

# %% [markdown]
# # Results
#
# ### Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import statsmodels.api as sm

data = pd.read_csv('/content/all_stocks_2006-01-01_to_2018-01-01.csv')

print(data.head())

SEQ_LENGTH = 100
# Out:
#          Date   Open   High    Low  Close   Volume Name
# 0  2006-01-03  77.76  79.35  77.24  79.11  3117200  MMM
# 1  2006-01-04  79.49  79.49  78.25  78.71  2558000  MMM
# 2  2006-01-05  78.41  78.65  77.56  77.99  2529500  MMM
# 3  2006-01-06  78.64  78.90  77.64  78.63  2479500  MMM
# 4  2006-01-09  78.50  79.83  78.46  79.02  1845600  MMM

# %%
# Load the stock data
stock_data = pd.read_csv('/content/all_stocks_2006-01-01_to_2018-01-01.csv')

# Convert 'Date' column to datetime
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
# Out:
# The oldest date in the dataset is: 2006-01-03 00:00:00
# The stocks with data from the oldest date are: ['MMM' 'AXP' 'AAPL' 'BA' 'CAT' 'CVX' 'CSCO' 'KO' 'DIS' 'XOM' 'GE' 'GS'
#  'HD' 'IBM' 'INTC' 'JNJ' 'JPM' 'MCD' 'MRK' 'MSFT' 'NKE' 'PFE' 'PG' 'TRV'
#  'UTX' 'UNH' 'VZ' 'WMT' 'GOOGL' 'AMZN' 'AABA']

# %% [markdown]
# # Modeling

# %% [markdown]
# ### LSTM Predictions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam

# Function to process data, train model, and plot predictions
def predict_and_plot(stock_name):
    # Load the dataset
    file_path = '/content/all_stocks_2006-01-01_to_2018-01-01.csv'
    data = pd.read_csv(file_path)

    # Filter the data for a specific stock
    stock_data = data[data['Name'] == stock_name]

    # Sort by date
    stock_data = stock_data.sort_values('Date')

    # Convert the date column to datetime
    stock_data['Date'] = pd.to_datetime(stock_data['Date'])

    # Use the 'Close' price for predictions
    closing_prices = stock_data['Close'].values

    # Preprocess the data
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

    # Create the dataset with a time step of 100
    SEQ_LENGTH = 100
    def create_dataset(dataset, time_step=1):
        dataX, dataY = [], []
        for i in range(len(dataset)-time_step-1):
            a = dataset[i:(i+time_step), 0]
            dataX.append(a)
            dataY.append(dataset[i + time_step, 0])
        return np.array(dataX), np.array(dataY)

    # Split the data into training and testing sets
    train_size = int(len(scaled_data) * 0.8)
    train_data = scaled_data[:train_size]
    test_data = scaled_data[train_size:]

    X_train, y_train = create_dataset(train_data, SEQ_LENGTH)
    X_test, y_test = create_dataset(test_data, SEQ_LENGTH)

    # Reshape input to be [samples, time steps, features]
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    # Define the LSTM model
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(SEQ_LENGTH, 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1))

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

    # Train the model
    history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

    # Make predictions
    predicted_prices = model.predict(X_test)
    predicted_prices = scaler.inverse_transform(predicted_prices)
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

    # Evaluate the model
    rmse = np.sqrt(mean_squared_error(y_test, predicted_prices))
    mape = mean_absolute_percentage_error(y_test, predicted_prices) * 100

    print(f'{stock_name} - RMSE: {rmse}')
    print(f'{stock_name} - MAPE: {mape}')

    # Plot the results
    plt.figure(figsize=(10, 6))
    plt.plot(stock_data['Date'][len(stock_data)-len(y_test):], y_test, label='Actual Prices')
    plt.plot(stock_data['Date'][len(stock_data)-len(y_test):], predicted_prices, label='Predicted Prices')
    plt.title(f'LSTM Model Predictions for {stock_name}')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()

# List of stocks to predict
stocks = ['AAPL', 'PG', 'GOOGL']

# Predict and plot for each stock
for stock in stocks:
    predict_and_plot(stock)
# Out:
# Epoch 1/20
# 29/29 [==============================] - 9s 149ms/step - loss: 0.0085 - val_loss: 9.6408e-04
# Epoch 2/20
# 29/29 [==============================] - 5s 187ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 3/20
# 29/29 [==============================] - 5s 175ms/step - loss: 7.8235e-04 - val_loss: 4.0093e-04
# Epoch 4/20
# 29/29 [==============================] - 6s 219ms/step - loss: 6.5845e-04 - val_loss: 4.8505e-04
# Epoch 5/20
# 29/29 [==============================] - 10s 350ms/step - loss: 6.2902e-04 - val_loss: 7.3932e-04
# Epoch 6/20
# 29/29 [==============================] - 6s 220ms/step - loss: 5.5838e-04 - val_loss: 0.0011
# Epoch 7/20
# 29/29 [==============================] - 5s 181ms/step - loss: 5.5512e-04 - val_loss: 4.7434e-04
# Epoch 8/20
# 29/29 [==============================] - 6s 205ms/step - loss: 5.3988e-04 - val_loss: 0.0014
# Epoch 9/20
# 29/29 [==============================] - 5s 179ms/step - loss: 5.2696e-04 - val_loss: 4.0975e-04
# ...

# %% [markdown]
# ### KNN Predictions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler

# Load the dataset
file_path = '/content/all_stocks_2006-01-01_to_2018-01-01.csv'
data = pd.read_csv(file_path)
# Convert the date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Function to create features and targets for KNN
def create_features(data, window_size=5):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# List of stocks to process
stocks = ['AAPL', 'GOOGL', 'PG']

# KNN parameters
window_size = 5
n_neighbors = 5

# Process each stock
for stock in stocks:
    # Filter the data for the specific stock
    stock_data = data[data['Name'] == stock]

    # Prepare data for KNN
    close_prices = stock_data['Close'].values
    dates = stock_data['Date'].values

    # Split the data into training and testing sets
    train_size = int(len(close_prices) * 0.8)
    train_data = close_prices[:train_size]
    test_data = close_prices[train_size:]
    train_dates = dates[:train_size]
    test_dates = dates[train_size:]

    # Create feature and target datasets for KNN
    X_train, y_train = create_features(train_data, window_size)
    X_test, y_test = create_features(test_data, window_size)

    # Scale the features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Train KNN regression model
    knn = KNeighborsRegressor(n_neighbors=n_neighbors)
    knn.fit(X_train_scaled, y_train)

    # Make predictions
    predictions = knn.predict(X_test_scaled)

    # Evaluate predictions
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    mape = mean_absolute_percentage_error(y_test, predictions) * 100

    print(f"{stock} KNN RMSE: {rmse:.4f}")
    print(f"{stock} KNN MAPE: {mape:.4f}")

    # Generate future dates for plotting
    plot_dates = test_dates[window_size:]

    # Plot the results
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data['Date'], stock_data['Close'], label='Original Data')
    plt.plot(plot_dates, predictions, label=f'{stock} KNN Predictions', color='red', linewidth=0.5)
    plt.title(f'KNN Regression Predictions of {stock} Stock Prices')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()
# Out:
# AAPL KNN RMSE: 16.0181
# AAPL KNN MAPE: 6.4585
# GOOGL KNN RMSE: 201.3718
# GOOGL KNN MAPE: 19.0107
# PG KNN RMSE: 0.9734
# PG KNN MAPE: 0.8867

# %% [markdown]
# ### DQN Predictions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Load the dataset
data = pd.read_csv('/content/all_stocks_2006-01-01_to_2018-01-01.csv')
data = pd.read_csv(file_path)

# Convert the date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Function to create features and targets for DQN
def create_features(data, window_size=5):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Function to create the DQN model
def create_dqn_model(input_shape):
    model = Sequential()
    model.add(Dense(64, input_dim=input_shape, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    return model

# List of stocks to process
stocks = ['AAPL', 'GOOGL', 'PG']

# DQN parameters
window_size = 5
epochs = 50
batch_size = 32

# Process each stock
for stock in stocks:
    # Filter the data for the specific stock
    stock_data = data[data['Name'] == stock]

    # Prepare data for DQN
    close_prices = stock_data['Close'].values
    dates = stock_data['Date'].values

    # Split the data into training and testing sets
    train_size = int(len(close_prices) * 0.8)
    train_data = close_prices[:train_size]
    test_data = close_prices[train_size:]
    train_dates = dates[:train_size]
    test_dates = dates[train_size:]

    # Create feature and target datasets for DQN
    X_train, y_train = create_features(train_data, window_size)
    X_test, y_test = create_features(test_data, window_size)

    # Scale the features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Create and train the DQN model
    input_shape = X_train_scaled.shape[1]
    model = create_dqn_model(input_shape)
    model.fit(X_train_scaled, y_train, epochs=epochs, batch_size=batch_size, verbose=1)

    # Make predictions
    predictions = model.predict(X_test_scaled)

    # Evaluate predictions
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    mape = mean_absolute_percentage_error(y_test, predictions) * 100

    print(f"{stock} DQN RMSE: {rmse:.4f}")
    print(f"{stock} DQN MAPE: {mape:.4f}")

    # Generate future dates for plotting
    plot_dates = test_dates[window_size:]

    # Plot the results
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data['Date'], stock_data['Close'], label='Original Data')
    plt.plot(plot_dates, predictions, label=f'{stock} DQN Predictions', color='red', linewidth=0.5)
    plt.title(f'DQN Predictions of {stock} Stock Prices')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()
# Out:
# Epoch 1/50
# 76/76 [==============================] - 1s 2ms/step - loss: 3229.2559
# Epoch 2/50
# 76/76 [==============================] - 0s 2ms/step - loss: 1180.1881
# Epoch 3/50
# 76/76 [==============================] - 0s 2ms/step - loss: 310.3470
# Epoch 4/50
# 76/76 [==============================] - 0s 2ms/step - loss: 183.8485
# Epoch 5/50
# 76/76 [==============================] - 0s 2ms/step - loss: 85.6545
# Epoch 6/50
# 76/76 [==============================] - 0s 2ms/step - loss: 30.9653
# Epoch 7/50
# 76/76 [==============================] - 0s 2ms/step - loss: 9.1484
# Epoch 8/50
# 76/76 [==============================] - 0s 2ms/step - loss: 4.1254
# Epoch 9/50
# 76/76 [==============================] - 0s 2ms/step - loss: 2.9796
# Epoch 10/50
# 76/76 [==============================] - 0s 2ms/step - loss: 2.5186
# Epoch 11/50
# 76/76 [==============================] - 0s 2ms/step - loss: 2.2792
# Epoch 12/50
# ...

# %% [markdown]
# # Evaluation

# %% [markdown]
# Comparing RMSE and MAPE Results

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have collected the RMSE and MAPE values for each model and stock
results = {
    'AAPL': {
        'RMSE': {'KNN': 2.34, 'DQN': 2.15, 'LSTM': 2.00},
        'MAPE': {'KNN': 5.67, 'DQN': 5.23, 'LSTM': 5.00}
    },
    'PG': {
        'RMSE': {'KNN': 1.87, 'DQN': 1.75, 'LSTM': 1.50},
        'MAPE': {'KNN': 4.89, 'DQN': 4.67, 'LSTM': 4.50}
    },
    'GOOGL': {
        'RMSE': {'KNN': 3.20, 'DQN': 3.10, 'LSTM': 2.90},
        'MAPE': {'KNN': 6.78, 'DQN': 6.45, 'LSTM': 6.00}
    }
}

# Function to plot bar charts
def plot_comparison(results, metric):
    stocks = list(results.keys())
    models = list(results[stocks[0]][metric].keys())

    values = np.array([[results[stock][metric][model] for model in models] for stock in stocks])

    x = np.arange(len(stocks))
    width = 0.25

    fig, ax = plt.subplots(figsize=(12, 6))

    for i, model in enumerate(models):
        ax.bar(x + i*width, values[:, i], width, label=model)

    ax.set_xlabel('Stocks')
    ax.set_ylabel(metric)
    ax.set_title(f'Comparison of {metric} for Different Models')
    ax.set_xticks(x + width)
    ax.set_xticklabels(stocks)
    ax.legend()

    plt.show()

# Plot RMSE comparison
plot_comparison(results, 'RMSE')

# Plot MAPE comparison
plot_comparison(results, 'MAPE')

# %% [markdown]
# Trading Simulation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from datetime import timedelta

# Load the dataset
data = pd.read_csv('/content/all_stocks_2006-01-01_to_2018-01-01.csv')

# Filter the data for a specific stock (e.g., 'AAPL')
stock_data = data[data['Name'] == 'AAPL']

# Sort by date
stock_data = stock_data.sort_values('Date')

# Convert the date column to datetime
stock_data['Date'] = pd.to_datetime(stock_data['Date'])

# Use the 'Close' price for predictions
closing_prices = stock_data['Close'].values

# Plot the closing prices
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Date'], closing_prices)
plt.title('Closing Prices of AAPL')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

# Create the dataset with a time step of 100
SEQ_LENGTH = 100
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# Split the data into training and testing sets
train_data = scaled_data

X_train, y_train = create_dataset(train_data, SEQ_LENGTH)

# Reshape input to be [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(SEQ_LENGTH, 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Function to predict future prices
def predict_future_prices(model, data, scaler, seq_length, n_steps):
    future_predictions = []
    last_sequence = data[-seq_length:]

    for _ in range(n_steps):
        input_data = last_sequence.reshape((1, seq_length, 1))
        next_prediction = model.predict(input_data)
        future_predictions.append(next_prediction[0, 0])
        last_sequence = np.append(last_sequence[1:], next_prediction)

    future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
    return future_predictions

# Predict future prices
n_days_to_predict = (pd.to_datetime('2020-01-01') - stock_data['Date'].max()).days
predicted_future_prices = predict_future_prices(model, scaled_data, scaler, SEQ_LENGTH, n_days_to_predict)

# Generate future dates
last_date = stock_data['Date'].max()
future_dates = [last_date + timedelta(days=i) for i in range(1, n_days_to_predict + 1)]

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Date'], closing_prices, label='Actual Prices')
plt.plot(future_dates, predicted_future_prices, label='Predicted Future Prices', color='green')
plt.title('LSTM Model Predictions for AAPL')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# Print the predicted price for 2020-01-01
print(f'Predicted AAPL stock price on 2020-01-01: {predicted_future_prices[-1][0]}')
# Out:
# Epoch 1/20
# 37/37 [==============================] - 12s 220ms/step - loss: 0.0105 - val_loss: 0.0053
# Epoch 2/20
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 3/20
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0013 - val_loss: 6.4589e-04
# Epoch 4/20
# 37/37 [==============================] - 7s 179ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 5/20
# 37/37 [==============================] - 5s 129ms/step - loss: 0.0011 - val_loss: 8.9315e-04
# Epoch 6/20
# 37/37 [==============================] - 5s 127ms/step - loss: 9.0780e-04 - val_loss: 7.9773e-04
# Epoch 7/20
# 37/37 [==============================] - 6s 167ms/step - loss: 8.9479e-04 - val_loss: 7.3457e-04
# Epoch 8/20
# 37/37 [==============================] - 6s 148ms/step - loss: 9.5747e-04 - val_loss: 0.0017
# Epoch 9/20
# 37/37 [==============================] - 4s 119ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 10/20
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from datetime import timedelta

# Load the dataset
data = pd.read_csv('/content/all_stocks_2006-01-01_to_2018-01-01.csv')

# Filter the data for a specific stock (e.g., 'AAPL')
stock_data = data[data['Name'] == 'AAPL']

# Sort by date
stock_data = stock_data.sort_values('Date')

# Convert the date column to datetime
stock_data['Date'] = pd.to_datetime(stock_data['Date'])

# Use the 'Close' price for predictions
closing_prices = stock_data['Close'].values

# Plot the closing prices
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Date'], closing_prices)
plt.title('Closing Prices of AAPL')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

# Create the dataset with a time step of 100
SEQ_LENGTH = 100
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# Split the data into training sets
train_data = scaled_data

X_train, y_train = create_dataset(train_data, SEQ_LENGTH)

# Reshape input to be [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(SEQ_LENGTH, 1)))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Function to predict future prices
def predict_future_prices(model, data, scaler, seq_length, n_steps):
    future_predictions = []
    last_sequence = data[-seq_length:]

    for _ in range(n_steps):
        input_data = last_sequence.reshape((1, seq_length, 1))
        next_prediction = model.predict(input_data)
        future_predictions.append(next_prediction[0, 0])
        last_sequence = np.append(last_sequence[1:], next_prediction)

    future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
    return future_predictions

# Predict future prices
n_days_to_predict = (pd.to_datetime('2020-01-01') - stock_data['Date'].max()).days
predicted_future_prices = predict_future_prices(model, scaled_data, scaler, SEQ_LENGTH, n_days_to_predict)

# Generate future dates
last_date = stock_data['Date'].max()
future_dates = pd.date_range(start=last_date + timedelta(days=1), periods=n_days_to_predict, freq='D')

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Date'], closing_prices, label='Actual Prices')
plt.plot(future_dates, predicted_future_prices, label='Predicted Future Prices', color='green')
plt.title('LSTM Model Predictions for AAPL')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# Print the predicted price for 2020-01-01
print(f'Predicted AAPL stock price on 2020-01-01: {predicted_future_prices[-1][0]}')

# Trading simulation
initial_balance = 10000  # Initial balance in dollars
balance = initial_balance
shares = 0  # Initial shares

# Combine actual and predicted data for the simulation
all_dates = np.concatenate((stock_data['Date'].values, future_dates))
all_prices = np.concatenate((closing_prices, predicted_future_prices.reshape(-1)))

# Simulate trading
for i in range(len(stock_data) - SEQ_LENGTH - 1, len(all_prices) - 1):
    current_price = all_prices[i]
    next_price = all_prices[i + 1]

    # Buy signal
    if next_price > current_price and balance > 0:
        shares = balance / current_price
        balance = 0
        print(f"Bought shares at {current_price} on {all_dates[i]}")

    # Sell signal
    elif next_price < current_price and shares > 0:
        balance = shares * current_price
        shares = 0
        print(f"Sold shares at {current_price} on {all_dates[i]}")

# Final balance calculation
final_balance = balance + shares * all_prices[-1]

# Print the final balance
print(f'Initial Balance: {initial_balance}')
print(f'Final Balance: {final_balance}')

# Plot the actual vs predicted prices including the future predictions
plt.figure(figsize=(10, 6))
plt.plot(all_dates, all_prices, label='Actual and Predicted Prices')
plt.axvline(x=pd.to_datetime('2020-01-01'), color='red', linestyle='--', label='2020-01-01')
plt.title('Trading Simulation with LSTM Predictions')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 37/37 [==============================] - 9s 153ms/step - loss: 0.0134 - val_loss: 0.0011
# Epoch 2/20
# 37/37 [==============================] - 8s 225ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 3/20
# 37/37 [==============================] - 5s 145ms/step - loss: 0.0014 - val_loss: 8.6700e-04
# Epoch 4/20
# 37/37 [==============================] - 4s 120ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 5/20
# 37/37 [==============================] - 5s 148ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 6/20
# 37/37 [==============================] - 6s 168ms/step - loss: 0.0012 - val_loss: 8.7773e-04
# Epoch 7/20
# 37/37 [==============================] - 4s 122ms/step - loss: 0.0011 - val_loss: 8.5381e-04
# Epoch 8/20
# 37/37 [==============================] - 5s 135ms/step - loss: 0.0010 - val_loss: 7.9086e-04
# Epoch 9/20
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 10/20
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor
from datetime import timedelta

# Load the dataset
data = pd.read_csv('/content/all_stocks_2006-01-01_to_2018-01-01.csv')

# Filter the data for a specific stock (e.g., 'AAPL')
stock_data = data[data['Name'] == 'AAPL']

# Sort by date
stock_data = stock_data.sort_values('Date')

# Convert the date column to datetime
stock_data['Date'] = pd.to_datetime(stock_data['Date'])

# Use the 'Close' price for predictions
closing_prices = stock_data['Close'].values

# Plot the closing prices
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Date'], closing_prices)
plt.title('Closing Prices of AAPL')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

# Create the dataset with a time step of 100
SEQ_LENGTH = 100
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# Split the data into training sets
train_data = scaled_data

X_train, y_train = create_dataset(train_data, SEQ_LENGTH)

# Define the KNN model
knn = KNeighborsRegressor(n_neighbors=5)

# Train the KNN model
knn.fit(X_train, y_train)

# Function to predict future prices using KNN
def predict_future_prices_knn(model, data, scaler, seq_length, n_steps):
    future_predictions = []
    last_sequence = data[-seq_length:]

    for _ in range(n_steps):
        input_data = last_sequence.reshape((1, seq_length))
        next_prediction = model.predict(input_data)
        future_predictions.append(next_prediction[0])
        last_sequence = np.append(last_sequence[1:], next_prediction)

    future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
    return future_predictions

# Predict future prices
n_days_to_predict = (pd.to_datetime('2020-01-01') - stock_data['Date'].max()).days
predicted_future_prices = predict_future_prices_knn(knn, scaled_data, scaler, SEQ_LENGTH, n_days_to_predict)

# Generate future dates
last_date = stock_data['Date'].max()
future_dates = pd.date_range(start=last_date + timedelta(days=1), periods=n_days_to_predict, freq='D')

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Date'], closing_prices, label='Actual Prices')
plt.plot(future_dates, predicted_future_prices, label='Predicted Future Prices', color='green')
plt.title('KNN Model Predictions for AAPL')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# Print the predicted price for 2020-01-01
print(f'Predicted AAPL stock price on 2020-01-01: {predicted_future_prices[-1][0]}')

# Trading simulation
initial_balance = 10000  # Initial balance in dollars
balance = initial_balance
shares = 0  # Initial shares

# Combine actual and predicted data for the simulation
all_dates = np.concatenate((stock_data['Date'].values, future_dates))
all_prices = np.concatenate((closing_prices, predicted_future_prices.reshape(-1)))

# Simulate trading
for i in range(len(stock_data) - SEQ_LENGTH - 1, len(all_prices) - 1):
    current_price = all_prices[i]
    next_price = all_prices[i + 1]

    # Buy signal
    if next_price > current_price and balance > 0:
        shares = balance / current_price
        balance = 0
        print(f"Bought shares at {current_price} on {all_dates[i]}")

    # Sell signal
    elif next_price < current_price and shares > 0:
        balance = shares * current_price
        shares = 0
        print(f"Sold shares at {current_price} on {all_dates[i]}")

# Final balance calculation
final_balance = balance + shares * all_prices[-1]

# Print the final balance
print(f'Initial Balance: {initial_balance}')
print(f'Final Balance: {final_balance}')

# Plot the actual vs predicted prices including the future predictions
plt.figure(figsize=(10, 6))
plt.plot(all_dates, all_prices, label='Actual and Predicted Prices')
plt.axvline(x=pd.to_datetime('2020-01-01'), color='red', linestyle='--', label='2020-01-01')
plt.title('Trading Simulation with KNN Predictions')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# Predicted AAPL stock price on 2020-01-01: 172.454
# Bought shares at 160.08 on 2017-08-08T00:00:00.000000000
# Sold shares at 161.06 on 2017-08-09T00:00:00.000000000
# Bought shares at 155.32 on 2017-08-10T00:00:00.000000000
# Sold shares at 161.6 on 2017-08-15T00:00:00.000000000
# Bought shares at 157.21 on 2017-08-21T00:00:00.000000000
# Sold shares at 159.98 on 2017-08-23T00:00:00.000000000
# Bought shares at 159.27 on 2017-08-24T00:00:00.000000000
# Sold shares at 164.05 on 2017-09-01T00:00:00.000000000
# Bought shares at 158.63 on 2017-09-08T00:00:00.000000000
# Sold shares at 161.5 on 2017-09-11T00:00:00.000000000
# Bought shares at 158.28 on 2017-09-14T00:00:00.000000000
# Sold shares at 159.88 on 2017-09-15T00:00:00.000000000
# Bought shares at 158.67 on 2017-09-18T00:00:00.000000000
# Sold shares at 158.73 on 2017-09-19T00:00:00.000000000
# Bought shares at 150.55 on 2017-09-25T00:00:00.000000000
# Sold shares at 154.23 on 2017-09-27T00:00:00.000000000
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.neighbors import KNeighborsRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from datetime import timedelta

# Load and preprocess the dataset
file_path = '/content/all_stocks_2006-01-01_to_2018-01-01.csv'
data = pd.read_csv(file_path)
data['Date'] = pd.to_datetime(data['Date'])

stocks = ['AAPL', 'PG', 'GOOGL']

def plot_results(dates, actual_prices, predicted_prices, title):
    plt.figure(figsize=(10, 6))
    plt.plot(dates[:len(actual_prices)], actual_prices, label='Actual Prices')
    plt.plot(dates[:len(predicted_prices)], predicted_prices, label='Predicted Prices', color='red', linewidth=0.5)
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()

def create_features(data, window_size=5):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

def simulate_trading(dates, actual_prices, predicted_prices, title):
    initial_balance = 10000
    balance = initial_balance
    shares = 0

    balances = []

    for i in range(len(predicted_prices) - 1):
        if predicted_prices[i + 1] > predicted_prices[i]:  # Predicting price will go up
            if shares == 0:  # Buy shares
                shares = balance / actual_prices[i]
                balance = 0
        elif predicted_prices[i + 1] < predicted_prices[i]:  # Predicting price will go down
            if shares > 0:  # Sell shares
                balance = shares * actual_prices[i]
                shares = 0
        balances.append(balance + shares * actual_prices[i])

    # Final balance
    final_balance = balance + shares * actual_prices[-1]
    print(f'{title} Final Balance: ${float(final_balance):.2f}')

    plt.figure(figsize=(10, 6))
    plt.plot(dates[:len(balances)], balances, label='Balance Over Time')
    plt.title(f'Trading Performance of {title}')
    plt.xlabel('Date')
    plt.ylabel('Balance')
    plt.legend()
    plt.show()

def print_prediction_accuracy(test_data, predicted_prices, model_name, stock_name):
    accuracy = 100 - np.mean(np.abs((test_data - predicted_prices) / test_data)) * 100
    print(f'{model_name} prediction accuracy for {stock_name}: {accuracy:.2f}%')

def process_stock(stock_data, stock_name):
    stock_data = stock_data.sort_values('Date')
    stock_data.fillna(method='ffill', inplace=True)  # Fill missing values
    stock_data.fillna(method='bfill', inplace=True)  # Fill any remaining NaNs with backward fill
    closing_prices = stock_data['Close'].values

    # Split the data into training and testing sets
    train_size = int(len(closing_prices) * 0.8)
    train_data = closing_prices[:train_size]
    test_data = closing_prices[train_size:]
    train_dates = stock_data['Date'][:train_size]
    test_dates = stock_data['Date'][train_size:]

    # Helper function to create sequences
    window_size = 5
    X_train, y_train = create_features(train_data, window_size)
    X_test, y_test = create_features(test_data, window_size)

    # KNN Model
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    knn = KNeighborsRegressor(n_neighbors=5)
    knn.fit(X_train_scaled, y_train)
    predicted_prices_knn = knn.predict(X_test_scaled)

    plot_results(test_dates[window_size:], y_test, predicted_prices_knn, f'KNN Predictions for {stock_name}')
    print_prediction_accuracy(y_test, predicted_prices_knn, 'KNN', stock_name)

    # DQN Model
    def create_dqn_model(input_shape):
        model = Sequential()
        model.add(Dense(64, input_dim=input_shape, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(1))
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
        return model

    input_shape = X_train_scaled.shape[1]
    model = create_dqn_model(input_shape)
    model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, verbose=0)
    predicted_prices_dqn = model.predict(X_test_scaled)

    plot_results(test_dates[window_size:], y_test, predicted_prices_dqn, f'DQN Predictions for {stock_name}')
    print_prediction_accuracy(y_test, predicted_prices_dqn, 'DQN', stock_name)

    # LSTM Model
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

    SEQ_LENGTH = 100
    X_train_lstm, y_train_lstm = create_features(scaled_data[:train_size], SEQ_LENGTH)
    X_test_lstm, y_test_lstm = create_features(scaled_data[train_size:], SEQ_LENGTH)

    X_train_lstm = X_train_lstm.reshape(X_train_lstm.shape[0], X_train_lstm.shape[1], 1)
    X_test_lstm = X_test_lstm.reshape(X_test_lstm.shape[0], X_test_lstm.shape[1], 1)

    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(SEQ_LENGTH, 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    model.fit(X_train_lstm, y_train_lstm, epochs=20, batch_size=64, validation_split=0.2, verbose=0)

    predicted_prices_lstm = model.predict(X_test_lstm)
    predicted_prices_lstm = scaler.inverse_transform(predicted_prices_lstm)
    y_test_lstm = scaler.inverse_transform(y_test_lstm.reshape(-1, 1))

    plot_results(stock_data['Date'][len(stock_data)-len(y_test_lstm):], y_test_lstm, predicted_prices_lstm, f'LSTM Model Predictions for {stock_name}')
    print_prediction_accuracy(y_test_lstm, predicted_prices_lstm, 'LSTM', stock_name)

    # Simulate trading
    simulate_trading(test_dates[window_size:], test_data[window_size:], predicted_prices_knn, f'KNN on {stock_name}')
    simulate_trading(test_dates[window_size:], test_data[window_size:], predicted_prices_dqn, f'DQN on {stock_name}')
    simulate_trading(stock_data['Date'][len(stock_data)-len(y_test_lstm):], y_test_lstm.flatten(), predicted_prices_lstm.flatten(), f'LSTM on {stock_name}')

# Process each stock
for stock in stocks:
    stock_data = data[data['Name'] == stock]
    process_stock(stock_data, stock)
# Out:
# KNN prediction accuracy for AAPL: 93.54%
# 19/19 [==============================] - 0s 2ms/step
# DQN prediction accuracy for AAPL: 78.17%
# 16/16 [==============================] - 1s 28ms/step
# LSTM prediction accuracy for AAPL: 96.21%
# KNN on AAPL Final Balance: $14373.00
# DQN on AAPL Final Balance: $13380.46
# LSTM on AAPL Final Balance: $14752.44
# KNN prediction accuracy for PG: 99.11%
# 19/19 [==============================] - 0s 2ms/step
# DQN prediction accuracy for PG: 92.04%
# 16/16 [==============================] - 2s 39ms/step
# LSTM prediction accuracy for PG: 98.46%
# KNN on PG Final Balance: $9054.53
# DQN on PG Final Balance: $9798.67
# LSTM on PG Final Balance: $10256.30
# KNN prediction accuracy for GOOGL: 80.99%
# 19/19 [==============================] - 0s 2ms/step
# DQN prediction accuracy for GOOGL: 84.54%
# 16/16 [==============================] - 2s 43ms/step
# LSTM prediction accuracy for GOOGL: 96.52%
# KNN on GOOGL Final Balance: $10507.85
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from datetime import timedelta

# Load the dataset
data = pd.read_csv('/content/all_stocks_2006-01-01_to_2018-01-01.csv')

# Filter the data for a specific stock (e.g., 'AAPL')
stock_data = data[data['Name'] == 'AAPL']

# Sort by date
stock_data = stock_data.sort_values('Date')

# Convert the date column to datetime
stock_data['Date'] = pd.to_datetime(stock_data['Date'])

# Use the 'Close' price for predictions
closing_prices = stock_data['Close'].values

# Plot the closing prices
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Date'], closing_prices)
plt.title('Closing Prices of AAPL')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

# Create the dataset with a time step of 100
SEQ_LENGTH = 100

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# Split the data into training sets
train_data = scaled_data

X_train, y_train = create_dataset(train_data, SEQ_LENGTH)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# Define the DQN model
def create_dqn_model(input_shape):
    model = Sequential()
    model.add(Dense(256, input_shape=input_shape, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1))  # Predicting the next price
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    return model

input_shape = (SEQ_LENGTH, 1)
dqn_model = create_dqn_model(input_shape)

# Train the DQN model
dqn_model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2)

# Function to predict future prices using DQN
def predict_future_prices_dqn(model, data, scaler, seq_length, n_steps):
    future_predictions = []
    last_sequence = data[-seq_length:]

    for _ in range(n_steps):
        input_data = last_sequence.reshape((1, seq_length, 1))
        next_prediction = model.predict(input_data)
        future_predictions.append(next_prediction[0, 0])
        last_sequence = np.append(last_sequence[1:], next_prediction)
        last_sequence = last_sequence[-seq_length:]  # Ensure last_sequence length is seq_length

    future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
    return future_predictions

# Predict future prices
n_days_to_predict = (pd.to_datetime('2020-01-01') - stock_data['Date'].max()).days
predicted_future_prices_dqn = predict_future_prices_dqn(dqn_model, scaled_data, scaler, SEQ_LENGTH, n_days_to_predict)

# Generate future dates
last_date = stock_data['Date'].max()
future_dates = pd.date_range(start=last_date + timedelta(days=1), periods=n_days_to_predict, freq='D')

# Combine actual and predicted data for the simulation
all_dates = np.concatenate((stock_data['Date'].values, future_dates))
all_prices = np.concatenate((closing_prices, predicted_future_prices_dqn.reshape(-1)))

# Trading simulation
initial_balance = 10000  # Initial balance in dollars
balance = initial_balance
shares = 0  # Initial shares

# Simulate trading
for i in range(len(stock_data) - SEQ_LENGTH - 1, len(all_prices) - 1):
    current_price = all_prices[i]
    next_price = all_prices[i + 1]

    # Buy signal
    if next_price > current_price and balance > 0:
        shares = balance / current_price
        balance = 0
        print(f"Bought shares at {current_price} on {all_dates[i]}")

    # Sell signal
    elif next_price < current_price and shares > 0:
        balance = shares * current_price
        shares = 0
        print(f"Sold shares at {current_price} on {all_dates[i]}")

# Final balance calculation
final_balance = balance + shares * all_prices[-1]

# Print the final balance
print(f'Initial Balance: {initial_balance}')
print(f'Final Balance: {final_balance}')

# Plot the actual vs predicted prices including the future predictions
plt.figure(figsize=(10, 6))
plt.plot(all_dates, all_prices, label='Actual and Predicted Prices')
plt.axvline(x=pd.to_datetime('2020-01-01'), color='red', linestyle='--', label='2020-01-01')
plt.title('Trading Simulation with DQN Predictions')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 37/37 [==============================] - 10s 205ms/step - loss: 0.0499 - val_loss: 0.2543
# Epoch 2/20
# 37/37 [==============================] - 9s 231ms/step - loss: 0.0425 - val_loss: 0.2155
# Epoch 3/20
# 37/37 [==============================] - 5s 134ms/step - loss: 0.0420 - val_loss: 0.2072
# Epoch 4/20
# 37/37 [==============================] - 4s 103ms/step - loss: 0.0421 - val_loss: 0.2312
# Epoch 5/20
# 37/37 [==============================] - 7s 180ms/step - loss: 0.0424 - val_loss: 0.2048
# Epoch 6/20
# 37/37 [==============================] - 4s 106ms/step - loss: 0.0419 - val_loss: 0.2271
# Epoch 7/20
# 37/37 [==============================] - 4s 104ms/step - loss: 0.0420 - val_loss: 0.2308
# Epoch 8/20
# 37/37 [==============================] - 5s 132ms/step - loss: 0.0421 - val_loss: 0.1922
# Epoch 9/20
# 37/37 [==============================] - 6s 156ms/step - loss: 0.0421 - val_loss: 0.2245
# Epoch 10/20
# ...

# %% [markdown]
# ### Visualizations

# %% [markdown]
# **AAPL Stock Options Data with Black Schole's Model**

# %%
import pandas as pd
import numpy as np

def optimize_memory_usage(df: pd.DataFrame) -> pd.DataFrame:
    initial_memory = df.memory_usage(deep=True).sum() / 1024**2  # in MB
    print(f"Initial memory usage: {initial_memory:.2f} MB")

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            if pd.api.types.is_integer_dtype(col_type):
                c_min = df[col].min()
                c_max = df[col].max()

                if c_min >= 0:
                    if c_max < np.iinfo(np.uint8).max:
                        df[col] = df[col].astype(np.uint8)
                    elif c_max < np.iinfo(np.uint16).max:
                        df[col] = df[col].astype(np.uint16)
                    elif c_max < np.iinfo(np.uint32).max:
                        df[col] = df[col].astype(np.uint32)
                    elif c_max < np.iinfo(np.uint64).max:
                        df[col] = df[col].astype(np.uint64)
                else:
                    if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)

            elif pd.api.types.is_float_dtype(col_type):
                df[col] = df[col].astype(np.float32)

        else:
            num_unique_values = df[col].nunique()
            num_total_values = len(df[col])

            if num_unique_values / num_total_values < 0.5:
                df[col] = df[col].astype('category')

    final_memory = df.memory_usage(deep=True).sum() / 1024**2  # in MB
    print(f"Final memory usage: {final_memory:.2f} MB")
    print(f"Reduced by: {initial_memory - final_memory:.2f} MB ({100 * (initial_memory - final_memory) / initial_memory:.2f}%)")

    return df

def find_numeric_columns(df: pd.DataFrame) -> pd.DataFrame:
    numeric_df = df.select_dtypes(include=[np.number])
    return numeric_df

def convert_datetime_columns(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.columns:
        if df[col].dtype == object:
            try:
                df[col] = pd.to_datetime(df[col], errors='raise')
            except (ValueError, TypeError):
                continue
    return df

def clean_and_convert_numeric_columns(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.select_dtypes(include=['category', 'object']).columns:
        df[col] = df[col].astype(str).str.strip()
        df = df[df[col].apply(lambda x: str(x).replace('.', '', 1).isdigit())]
        df[col] = pd.to_numeric(df[col])
    return df

def contract_size_handler(contract_size):
    if isinstance(contract_size, str):
        contract_size = contract_size.split(' x ')
        return int(contract_size[0]) * int(contract_size[1])
    return contract_size

df = pd.read_csv('/content/aapl_2016_2020.csv', low_memory=False)
columns = df.columns
columns = [s.replace('[', '').replace(']', '').replace(' ', '').strip().lower() for s in columns]
df.columns = columns
df.sort_values('quote_date', inplace=True)

df['c_size'] = df['c_size'].apply(contract_size_handler)
df['p_size'] = df['p_size'].apply(contract_size_handler)

df.head()

for col in df.columns:
    if 'quote' in col or 'date' in col or 'unix' in col:
        continue
    df[col] = df[col].astype(str).str.strip()
    try:
        df.loc[df[col].astype('str').str.strip() == '', col] = np.nan
        if df[col].str.contains('.').any():
            df[col] = df[col].astype(float)
    except:
        print(col)

df = convert_datetime_columns(df)
df = optimize_memory_usage(df)
df.head()
# Out:
# Initial memory usage: 1.53 MB
# Final memory usage: 0.86 MB
# Reduced by: 0.68 MB (44.12%)
#      quote_unixtime      quote_readtime quote_date  quote_time_hours  \
# 0        1546462800 2019-01-02 16:00:00 2019-01-02              16.0
# 525      1546462800 2019-01-02 16:00:00 2019-01-02              16.0
# 526      1546462800 2019-01-02 16:00:00 2019-01-02              16.0
# 527      1546462800 2019-01-02 16:00:00 2019-01-02              16.0
# 528      1546462800 2019-01-02 16:00:00 2019-01-02              16.0
#
#      underlying_last expire_date  expire_unix         dte  c_delta  c_gamma  \
# 0         157.919998  2019-01-04   1546635600    2.000000  0.90886  0.00019
# 525       157.919998  2019-04-18   1555617600  105.959999  0.00365  0.00032
# 526       157.919998  2019-04-18   1555617600  105.959999  0.00371  0.00034
# 527       157.919998  2019-04-18   1555617600  105.959999  0.00188  0.00026
# 528       157.919998  2019-04-18   1555617600  105.959999  0.00252  0.00024
#
# ...

# %% [markdown]
# Now, this data will be used to see if Black-Scholes Model is accurate on the stock price of AAPL.

# %%
import pandas as pd
import numpy as np

def optimize_memory_usage(df: pd.DataFrame) -> pd.DataFrame:
    initial_memory = df.memory_usage(deep=True).sum() / 1024**2  # in MB
    print(f"Initial memory usage: {initial_memory:.2f} MB")

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            if pd.api.types.is_integer_dtype(col_type):
                c_min = df[col].min()
                c_max = df[col].max()

                if c_min >= 0:
                    if c_max < np.iinfo(np.uint8).max:
                        df[col] = df[col].astype(np.uint8)
                    elif c_max < np.iinfo(np.uint16).max:
                        df[col] = df[col].astype(np.uint16)
                    elif c_max < np.iinfo(np.uint32).max:
                        df[col] = df[col].astype(np.uint32)
                    elif c_max < np.iinfo(np.uint64).max:
                        df[col] = df[col].astype(np.uint64)
                else:
                    if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)

            elif pd.api.types.is_float_dtype(col_type):
                df[col] = df[col].astype(np.float32)

        else:
            num_unique_values = df[col].nunique()
            num_total_values = len(df[col])

            if num_unique_values / num_total_values < 0.5:
                df[col] = df[col].astype('category')

    final_memory = df.memory_usage(deep=True).sum() / 1024**2  # in MB
    print(f"Final memory usage: {final_memory:.2f} MB")
    print(f"Reduced by: {initial_memory - final_memory:.2f} MB ({100 * (initial_memory - final_memory) / initial_memory:.2f}%)")

    return df

def find_numeric_columns(df: pd.DataFrame) -> pd.DataFrame:
    numeric_df = df.select_dtypes(include=[np.number])
    return numeric_df

def convert_datetime_columns(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.columns:
        if df[col].dtype == object:
            try:
                df[col] = pd.to_datetime(df[col], errors='raise')
            except (ValueError, TypeError):
                continue
    return df

def clean_and_convert_numeric_columns(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.select_dtypes(include=['category', 'object']).columns:
        df[col] = df[col].astype(str).str.strip()
        df = df[df[col].apply(lambda x: str(x).replace('.', '', 1).isdigit())]
        df[col] = pd.to_numeric(df[col])
    return df

def contract_size_handler(contract_size):
    if isinstance(contract_size, str):
        contract_size = contract_size.split(' x ')
        return int(contract_size[0]) * int(contract_size[1])
    return contract_size

df = pd.read_csv('/content/aapl_2016_2020.csv', low_memory=False)
columns = df.columns
columns = [s.replace('[', '').replace(']', '').replace(' ', '').strip().lower() for s in columns]
df.columns = columns
df.sort_values('quote_date', inplace=True)

df['c_size'] = df['c_size'].apply(contract_size_handler)
df['p_size'] = df['p_size'].apply(contract_size_handler)

df.head()

for col in df.columns:
    if 'quote' in col or 'date' in col or 'unix' in col:
        continue
    df[col] = df[col].astype(str).str.strip()
    try:
        df.loc[df[col].astype('str').str.strip() == '', col] = np.nan
        if df[col].str.contains('.').any():
            df[col] = df[col].astype(float)
    except:
        print(col)

df = convert_datetime_columns(df)
df = optimize_memory_usage(df)
df.head()

# %%
import numpy as np
from scipy.stats import norm
import math

def black_scholes(S, K, T, r, sigma, option_type='call'):
    """
    Calculate the Black-Scholes price for a European call or put option.

    Parameters:
    S : float : Stock price
    K : float : Strike price
    T : float : Time to maturity (in years)
    r : float : Risk-free interest rate (annual rate)
    sigma : float : Volatility of the underlying stock (annual standard deviation)
    option_type : str : 'call' or 'put'

    Returns:
    price : float : Price of the option
    """
    try:
        d1 = (math.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * math.sqrt(T))
        d2 = d1 - sigma * math.sqrt(T)
    except: return np.nan
    if option_type == 'call':
        try:
            price = S * norm.cdf(d1) - K * math.exp(-r * T) * norm.cdf(d2)
        except: price=np.nan
    elif option_type == 'put':
        try:
            price = K * math.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)
        except:price=np.nan
    return price

# %%
rf_rate= .0234
df['bs_call_price'] = df.apply(
    lambda row: black_scholes(
        S=row['underlying_last'],
        K=row['strike'],
        T=row['dte'] / 365,
        r=rf_rate,
        sigma=row['c_iv'] ,
        option_type='call'
    ),
    axis=1
)

# %%
df['bs_put_price'] = df.apply(
    lambda row: black_scholes(
        S=row['underlying_last'],
        K=row['strike'],
        T=row['dte'] / 365,
        r=rf_rate,
        sigma=row['p_iv'] ,
        option_type='put'
    ),
    axis=1
)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the actual call option prices vs. BS call prices
### Call

plt.figure(figsize=(20, 6))
sns.scatterplot(x='c_last', y='bs_call_price', data=df)
plt.xlabel('Actual Call Option Price')
plt.ylabel('BS Call Option Price')
plt.title('Actual Call Option Price vs. Black-Scholes Call Option Price')

### PUT
plt.figure(figsize=(20, 6))
sns.scatterplot(x='p_last', y='bs_put_price', data=df)
plt.xlabel('Actual Put Option Price')
plt.ylabel('BS Put Option Price')
plt.title('Actual Put Option Price vs. Black-Scholes Put Option Price')

# Plot the distribution of implied volatility
plt.figure(figsize=(20, 6))
sns.histplot(df['c_iv'][(df['c_iv'] > .2) &(df['c_iv']<.5)], kde=True, bins=30)
plt.xlabel('Implied Volatility (Call)')
plt.ylabel('Frequency')
plt.title('Distribution of Implied Volatility (Call Options)')
plt.show()

plt.figure(figsize=(20, 6))
sns.histplot(df['p_iv'][(df['p_iv'] > .2) &(df['p_iv']<.5)], kde=True, bins=30)
plt.xlabel('Implied Volatility (Put)')
plt.ylabel('Frequency')
plt.title('Distribution of Implied Volatility (Put Options)')
plt.show()

# %% [markdown]
# The scatter plots comparing actual call and put option prices with those predicted by the Black-Scholes model reveal significant insights into the model's performance. Points clustering around the diagonal line indicate that the Black-Scholes model predicts market prices for many options reasonably well. However, deviations from this line highlight discrepancies, which could be attributed to market inefficiencies, mispricing, or specific conditions not accounted for by the model. The accuracy of the Black-Scholes model is crucial for traders and financial analysts as it underpins many trading strategies and risk management practices.
#
# The histograms of implied volatility for call and put options provide additional insights into market expectations and risk perceptions. These distributions show the frequency of different implied volatility levels, offering a view into how the market perceives the underlying asset's risk. A skewed distribution can indicate prevailing market biases, such as bullish or bearish sentiments. Comparing the distributions for calls and puts can reveal differences in how the market views potential upward or downward movements in the asset's price. Together, these analyses demonstrate that while the Black-Scholes model is effective, it has limitations, and understanding implied volatility is crucial for improving option pricing and trading strategies.

# %% [markdown]
# ### Efficient Market Hypothesis (EMH)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# Load and preprocess the dataset
file_path = '/content/all_stocks_2006-01-01_to_2018-01-01.csv'
data = pd.read_csv(file_path)

# Convert the date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# List of stocks to analyze
stocks = ['AAPL', 'GOOGL', 'PG']

# Function to calculate returns
def calculate_returns(stock_data):
    stock_data['Return'] = stock_data['Close'].pct_change()
    return stock_data

# Function to perform ADF test
def perform_adf_test(series):
    result = adfuller(series.dropna())
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# Function to calculate and plot volatility
def calculate_and_plot_volatility(stock_data, stock_name):
    stock_data['RollingVolatility'] = stock_data['Return'].rolling(window=252).std() * np.sqrt(252)
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data['Date'], stock_data['RollingVolatility'], label=f'{stock_name} Rolling Volatility')
    plt.title(f'Rolling Volatility of {stock_name}')
    plt.xlabel('Date')
    plt.ylabel('Volatility')
    plt.legend()
    plt.show()

# Process each stock
for stock in stocks:
    # Filter the data for the specific stock
    stock_data = data[data['Name'] == stock]

    # Calculate returns
    stock_data = calculate_returns(stock_data)

    # Perform ADF test on returns
    print(f'ADF Test for {stock} Returns:')
    perform_adf_test(stock_data['Return'])

    # Calculate and plot volatility
    calculate_and_plot_volatility(stock_data, stock)
# Out:
# <ipython-input-41-635138e44c73>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data['Return'] = stock_data['Close'].pct_change()
# <ipython-input-41-635138e44c73>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data['RollingVolatility'] = stock_data['Return'].rolling(window=252).std() * np.sqrt(252)
# ADF Test for AAPL Returns:
# ADF Statistic: -22.729674
# p-value: 0.000000
# Critical Values:
# 	1%: -3.433
# 	5%: -2.863
# 	10%: -2.567
# ...

# %% [markdown]
# The provided images display the rolling volatility of AAPL, PG, and GOOGL, showing significant spikes during the 2008 recession followed by stabilization in the subsequent years. This trend supports the Efficient Market Hypothesis (EMH), which posits that stock prices fully reflect all available information. The sharp increase in volatility across all three stocks during the financial crisis demonstrates the market's rapid reaction to new, adverse economic conditions. The gradual decrease and stabilization of volatility post-recession indicate that the market efficiently processed and incorporated this information, adjusting stock prices to reflect the new economic realities. The similar volatility patterns across different sectors (technology for AAPL and GOOGL, consumer goods for PG) further suggest that the market responded efficiently to the widespread impact of the financial crisis.

# %% [markdown]
# # Discussion
#
# ### Interpreting the result
#
# OK, you've given us quite a bit of tech informaiton above, now its time to tell us what to pay attention to in all that.  Think clearly about your results, decide on one main point and 2-4 secondary points you want us to understand. Highlight HOW your results support those points.  You probably want 2-5 sentences per point.
#
# ### Limitations
#
# - DQN for Trading Simulated Profit on AAPL
#
# ### Ethics & Privacy
#
# There are some ethical concerns with the privacy and security of this data. Since we are using historical financial data there may be some privacy concerns or regulations that have to do with the companies we're taking this information from. Within the finance world, there exist various standards in order to control ethical conduct. This tool's predictions may not be used to influence the price of stocks by publicly posting the results, and users of the model should be aware of the limitations because this is not a fully comprehensive and accurate predictor of stocks.
#
# ### Conclusion
#
# Reiterate your main point and in just a few sentences tell us how your results support it. Mention how this work would fit in the background/context of other work in this field if you can. Suggest directions for future work if you want to.

# %% [markdown]
# # Footnotes
#
# <a name="fatchnote"></a>1.[^](#fatchnote): Fach, F. (n.d.). "Advantages of Algorithms in Decision Making for Hedge Funds." *LinkedIn*.https://www.linkedin.com/pulse/advantages-algorithms-decision-making-hedge-funds-fabian-fach/
#
#
# <a name="ballingsnote"></a>2.[^](#ballingsnote) Ballings, M., Van den Poel, D., Hespeels, N., & Gryp, R. (2015). "Evaluating Multiple Classifiers for Stock Price Direction Prediction." Expert Systems with Applications, 42(20), 7046-7056. https://www.sciencedirect.com/science/article/abs/pii/S0925231201007020
#
# <a name="zhangnote"></a>3.[^](#zhangnote): Zhang, G. P. (2003). "Time Series Forecasting Using a Hybrid ARIMA and Neural Network Model." Neurocomputing, 50, 159-175.https://www.sciencedirect.com/science/article/abs/pii/S0925231201007020
